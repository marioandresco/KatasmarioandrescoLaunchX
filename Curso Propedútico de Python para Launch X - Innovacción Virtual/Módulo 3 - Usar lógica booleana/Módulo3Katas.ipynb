# %% [markdown]
# # ¿Cuándo los asteroides representan un peligro para la Tierra?

# %% [markdown]
# ## Problema 1

# %%
asteroide = 49
if asteroide > 25:
    print('El asteroide SI es peligroso')
else:
    print('El asteroide NO es peligroso')
# Out:
# El asteroide SI es peligroso

# %% [markdown]
# ## Problema 2

# %%
asteroide = 19
if asteroide > 20:
    print('El aseteoride produce un rayo de luz, se puede ver')
elif asteroide == 20:
    print('El aseteoride produce un rayo de luz, se puede ver')
else:
    print('El aseteoride no produce un rayo de luz')
# Out:
# El aseteoride no produce un rayo de luz

# %% [markdown]
# ## Problema 3

# %%
velocidad_asteroide = 25
tamano_asteroide = 40
if velocidad_asteroide > 25 and tamano_asteroide > 25:
    print('El asteroide SI es peligroso')
elif velocidad_asteroide >= 20:
    print('El aseteoride produce un rayo de luz, se puede ver')
elif tamano_asteroide < 25:
    print('El aseteoride no produce un rayo de luz')
else:
    print('No hay nada')
# Out:
# El aseteoride produce un rayo de luz, se puede ver
